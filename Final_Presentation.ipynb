# %% [markdown]
# Menu creation is a constant ongoing process at NC State. We change out menu items regularly hoping to keep up with the changing tastes of our current students.

# %% [markdown]
# How do you predict whether college students are going to regulary choose to eat a healthy meal or a feel good, readily available meal (even if it's not healthy), if they will always choose the same foods over and over, or if their diet is wholly inconsisent?

# %% [markdown]
# I have built a model that takes self reported demographic and data from a group of college students that accurately predicts what their regular eating habits are about 70-80% of the time, which is significantly more accurate than guessing.  It can be hard to define what factors in a student's life have an impact on their eating habits, but giving the model the data and letting it weigh each category and explore interactions between the different categories, we can have it make reasonably accurate guesses for us that can help us predict what type of meal one of these students might choose on a regular basis.

# %% [markdown]
# The model is able to learn, for example, the significance of the choice of an image a student associates most with breakfast:

# %%
from IPython.display import Image
Image("breakfast1.png")

# %% [markdown]
# OR

# %%
from IPython.display import Image
Image("breakfast2.png")
