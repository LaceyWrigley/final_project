# %% [markdown]
# Final Project Part 1
#
#
# In my role as a food service supervisor on a college campus, I need to understand student eating habits. I have decision making capacity both on individual recipes and on menu build. There are two main goals in mind related to this. One is to offer healthy items that students will actually choose and enjoy. The second is to provide menus that students will choose over non-campus venues. If we can accurately predict what students will eat and have a good understanding of why, we can tailor our menus to meet both requirements as much as possible. This study whose data I am using was not done on my particular campus, but after working with this data, I hope to be able to collect and analyze similar data for current students NC State.

# %% [markdown]
# The target column to predict for this data set will be diet_current_coded.
# Likely feature columns: exercise, weight, ideal_diet_coded, fav_food, ethnic_food, on_off_campus, fav_cuisine_coded.

# %% [markdown]
# I want to discover if we can predict what type of diet they will actually follow based on what they say about their own ideals, circumstance, and preferences. I want to discover if and which of these variables carries the most weight in predicting. I need for the accuracy to be 95% or above in order to use this model for business purposes. There is a risk that, since students are self reporting most of this information, including the target column, any desicions made on what to change on a menu based on this data set may still not meet the goals.

# %% [markdown]
# Data Source: https://www.kaggle.com/borapajo/food-choices

# %%
import pandas as pd

# %%
food = pd.read_csv('food_coded.csv')

# %%
food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
food.sample(10) #I have a docx file with the keys for everything, and how the questions were presented.
# Out:
#       GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 39      3       2          1               720           NaN           980.0
# 116   3.4       1          1               610           NaN           420.0
# 25    2.8       1          2               720           3.0           420.0
# 28    3.2       2          1               610           2.0           420.0
# 58    3.5       1          1               610           3.0           420.0
# 115   3.3       2          1               610           4.0           980.0
# 70   3.73       1          1               610           3.0           980.0
# 19    2.2       2          1               430           2.0           420.0
# 5    2.25       1          1               610           3.0           980.0
# 17    3.6       2          1               430           3.0           980.0
#
#      coffee                                       comfort_food  \
# ...

# %%
food.shape #There appears to be enough data for the specifications of this assignment.
# Out:
# (125, 61)

# %%
food.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
# ...

# %%
food_nulls = food.loc[:, ['diet_current_coded','exercise', 'weight', 'ideal_diet_coded', 'fav_food', 
                          'ethnic_food', 'on_off_campus', 'fav_cuisine_coded']].isnull()
food_nulls.sum()
# Out:
# diet_current_coded     0
# exercise              13
# weight                 2
# ideal_diet_coded       0
# fav_food               2
# ethnic_food            0
# on_off_campus          1
# fav_cuisine_coded      0
# dtype: int64

# %% [markdown]
# There are some strings where there should be numbers and some some NaN values, mostly in the exercise column.
